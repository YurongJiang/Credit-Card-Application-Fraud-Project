# %% [markdown]
# # Replace NA with 365

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score as acc
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
data = pd.read_csv("FinalNewVariables.csv")
#file that after features creation and with NA values, and we will replace NA with 365 now

# %%
dataFraudLabel = pd.read_csv("applications data.csv")

# %%
dataFraudLabel.head()
# Out:
#    record      date        ssn  firstname  lastname        address   zip5  \
# 0       1  20160101  379070012   XRRAMMTR  SMJETJMJ  6861 EUTST PL   2765
# 1       2  20160101  387482503   MAMSTUJR  RTTEMRRR  7280 URASA PL  57169
# 2       3  20160101  200332444  SZMMUJEZS  EUSEZRAE  5581 RSREX LN  56721
# 3       4  20160101  747451317  SJJZSXRSZ  ETJXTXXS  1387 UJZXJ RD  35286
# 4       5  20160101   24065868  SSSXUEJMS  SSUUJXUZ   279 EAASA WY   3173
#
#         dob   homephone  fraud_label
# 0  19070626  1797504115            0
# 1  19340615  4164239415            1
# 2  19070626   216537580            0
# 3  19440430   132144161            0
# 4  19980315  6101082272            0

# %%
dataFraudLNew = dataFraudLabel.drop(columns = ['date','ssn','firstname','lastname','address','zip5','dob','homephone'])

# %%
dataFraudLNew.head()
# Out:
#    record  fraud_label
# 0       1            0
# 1       2            1
# 2       3            0
# 3       4            0
# 4       5            0

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                              0
# record                                  0
# diff_date.ssn                      835819
# diff_date.fulladdress              845066
# diff_date.nameDOB                  848150
# diff_date.homephone                 28244
# diff_date.ssn_fulladdress          860142
# diff_date.ssn_firstname            854398
# diff_date.ssn_lastname             854446
# diff_date.ssn_nameDOB              856624
# diff_date.ssn_homephone            857519
# diff_date.fulladdress_firstname    858899
# diff_date.fulladdress_lastname     857801
# diff_date.fulladdress_nameDOB      859957
# diff_date.fulladdress_homephone    855637
# diff_date.firstname_lastname       981892
# diff_date.firstname_nameDOB        984031
# diff_date.firstname_homephone      979701
# diff_date.lastname_nameDOB         963974
# diff_date.lastname_homephone       961158
# diff_date.nameDOB_homephone        858581
# ssn_risk                                0
# ...

# %%
data.shape
# Out:
# (1000000, 103)

# %%
data2 = data.iloc[:,1:]

# %%
data2.dtypes
# Out:
# record                               int64
# diff_date.ssn                      float64
# diff_date.fulladdress              float64
# diff_date.nameDOB                  float64
# diff_date.homephone                float64
# diff_date.ssn_fulladdress          float64
# diff_date.ssn_firstname            float64
# diff_date.ssn_lastname             float64
# diff_date.ssn_nameDOB              float64
# diff_date.ssn_homephone            float64
# diff_date.fulladdress_firstname    float64
# diff_date.fulladdress_lastname     float64
# diff_date.fulladdress_nameDOB      float64
# diff_date.fulladdress_homephone    float64
# diff_date.firstname_lastname       float64
# diff_date.firstname_nameDOB        float64
# diff_date.firstname_homephone      float64
# diff_date.lastname_nameDOB         float64
# diff_date.lastname_homephone       float64
# diff_date.nameDOB_homephone        float64
# ssn_risk                           float64
# fulladdress_risk                   float64
# ...

# %%
#data2.describe().transpose()

# %%
data3 = data2.fillna(365)

# %%
new = pd.merge(data3,dataFraudLNew,on = 'record')

# %%
new.tail(5)
# Out:
#          record  diff_date.ssn  diff_date.fulladdress  diff_date.nameDOB  \
# 999970   999971          357.0                  357.0              357.0
# 999971   999972          365.0                  365.0              365.0
# 999972   999973           28.0                   28.0               28.0
# 999973   999974          365.0                  365.0              365.0
# 999974   999975           33.0                   33.0               33.0
# 999975   999976          266.0                  266.0              266.0
# 999976   999977          365.0                  365.0              365.0
# 999977   999978          365.0                  365.0              365.0
# 999978   999979          365.0                  365.0              365.0
# 999979   999980           64.0                   64.0               64.0
# 999980   999981          365.0                  365.0              365.0
# 999981   999982          365.0                  365.0              365.0
# ...

# %%
new.isnull().sum().sum()
# Out:
# 0

# %%
new.to_csv("FinalCleanedVariablesNoNa.csv")
